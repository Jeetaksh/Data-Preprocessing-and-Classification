# %%
# %cd sample_data
# Out:
# /content/sample_data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the training split and test split

data = pd.read_csv('final.csv')
data = data.dropna()    # Remove any invalid rows. This will produce at 45552 rows. PRE-PROCESSING FINAL STEP.

X = data.drop('income_0', axis=1)       # axis = 1 means drop this income column. Retain just features.
y = data['income_0']

# Performed stratified split into training (38000 rows) and test (7000 rows)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 38000, test_size=7000, random_state=42, stratify=y)

# Concatenated X and y for both training and test sets
train_set = pd.concat([X_train, y_train], axis=1)  # 38,000 rows
test_set = pd.concat([X_test, y_test], axis=1)     # 7,000 rows

# %%
print(train_set)
# Out:
#        age  WORKCLASS  fnlwgt  educational_num  MARITAL_STATUS  occupation  \
# 0       39        5.0   77516               13               2         8.0
# 1       50        1.0   83311               13               0         4.0
# 2       38        0.0  215646                9               1         6.0
# 3       53        0.0  234721                7               0         6.0
# 4       28        0.0  338409               13               0         5.0
# ...    ...        ...     ...              ...             ...         ...
# 41034   45        0.0   72393               13               5         5.0
# 41035   55        2.0  160813                9               3         3.0
# 41036   43        0.0  255586                9               1         7.0
# 41037   21        0.0  342575               10               2         3.0
# 41038   28        0.0  181466                9               2         7.0
#
# ...

# %%
print(test_set)
# Out:
#        age  WORKCLASS  fnlwgt  educational_num  MARITAL_STATUS  occupation  \
# 41039   23        0.0  234108               12               2         7.0
# 41040   28        0.0   66414               13               0         5.0
# 41041   21        0.0  227307                9               0         8.0
# 41042   23        0.0  157145                9               3         7.0
# 41043   63        0.0  252457                9               4         4.0
# ...    ...        ...     ...              ...             ...         ...
# 48607   38        0.0  313914               13               3         9.0
# 48608   33        0.0  172584                9               2         8.0
# 48609   28        0.0  112425               13               1         0.0
# 48610   22        0.0  157783                9               0         2.0
# 48611   34        0.0  356882                9               0         0.0
#
# ...

# %%
age_counts = train_set['age'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.title('Number of People by Age')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = test_set['age'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.title('Number of People by Age')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = train_set['educational_num'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Education')
plt.ylabel('Number of People')
plt.title('Number of People by Education')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = test_set['educational_num'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Education')
plt.ylabel('Number of People')
plt.title('Number of People by Education')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = train_set['occupation'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Occupation')
plt.ylabel('Number of People')
plt.title('Number of People by Occupation')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = test_set['occupation'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('Occupation')
plt.ylabel('Number of People')
plt.title('Number of People by Occupation')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = train_set['MARITAL_STATUS'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('MARITAL_STATUS')
plt.ylabel('Number of People')
plt.title('Number of People by MARITAL_STATUS')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = test_set['MARITAL_STATUS'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('MARITAL_STATUS')
plt.ylabel('Number of People')
plt.title('Number of People by MARITAL_STATUS')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = train_set['gender'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('GENDER')
plt.ylabel('Number of People')
plt.title('Number of People by GENDER')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
age_counts = test_set['gender'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(25, 3))
plt.bar(age_counts.index, age_counts.values, color='blue')
plt.xlabel('GENDER')
plt.ylabel('Number of People')
plt.title('Number of People by GENDER')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
counts = train_set['income_0'].value_counts()
print(counts)

# Plot a pie char
plt.figure(figsize=(10, 6))
plt.pie(counts, labels=None, autopct='', startangle=90)
plt.gca().set_aspect('equal')

# Display percentages in the legend
percentages = ['{:.1f}%'.format(x) for x in (counts / counts.sum() * 100)]
labels_with_percentages = [f'{label} ({percentage})' for label, percentage in zip(counts.index, percentages)]

plt.legend(labels_with_percentages, title='Income', loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Target Distribution')
plt.show()
# Out:
# 0    28585
# 1     9415
# Name: income_0, dtype: int64

# %%
counts = test_set['income_0'].value_counts()
print(counts)

# Plot a pie char
plt.figure(figsize=(10, 6))
plt.pie(counts, labels=None, autopct='', startangle=90)
plt.gca().set_aspect('equal')

# Display percentages in the legend
percentages = ['{:.1f}%'.format(x) for x in (counts / counts.sum() * 100)]
labels_with_percentages = [f'{label} ({percentage})' for label, percentage in zip(counts.index, percentages)]

plt.legend(labels_with_percentages, title='Income', loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Target Distribution')
plt.show()
# Out:
# 0    5266
# 1    1734
# Name: income_0, dtype: int64
